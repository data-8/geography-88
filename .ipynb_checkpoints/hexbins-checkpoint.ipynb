# %%
# %matplotlib inline

import numpy as np
import math
import matplotlib.pyplot as plt

import shapely.geometry as geom

# %%
def make_centers(xmin=-180, xmax=180, ymin=-85, ymax=85, nrows=10):
    row_spacing = (ymax - ymin) / nrows
    col_spacing = 2 / math.sqrt(3) * row_spacing
    ncols = (xmax - xmin) / col_spacing
    x = ([(c + 0.25) * col_spacing + xmin for c in range(int(ncols))] 
     + [(c + 0.75) * col_spacing + xmin for c in range(int(ncols))]) * int(nrows / 2)
    y = [(r + 0.5) * row_spacing + ymin for r in range(int(nrows))] * int(ncols)
    y.sort()
    return (x, y)

def make_hexes(**kwargs):
    print(kwargs)
    centers = make_centers(kwargs)
    radius = (centers[0][1] - centers[0][0]) / math.sqrt(3)
    hexes = []
    for (x, y) in zip(centers[0], centers[1]):
        this_hex = []
        for theta in [(1/6 + i/3) * math.pi for i in range(6)]:
            this_hex.append((x + radius * math.cos(theta), y + radius * math.sin(theta)))
        hexes.append(geom.polygon.Polygon(this_hex))
    return hexes

# %%
xy = make_centers()
fig, ax = plt.subplots()
ax.set_aspect('equal')
plt.plot(xy[0], xy[1], marker='o', linestyle='None')

# %%
hexes = make_hexes(xmin=-150, xmax=-70, ymin=30, ymax=50, nrows=20)
# Out:
# {'xmin': -150, 'xmax': -70, 'ymin': 30, 'ymax': 50, 'nrows': 20}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-136-6664043e4c96> in <module>()
# ----> 1 hexes = make_hexes(xmin=-150, xmax=-70, ymin=30, ymax=50, nrows=20)
#
# <ipython-input-134-cc9e1ad84fbb> in make_hexes(**kwargs)
#      11 def make_hexes(**kwargs):
#      12     print(kwargs)
# ---> 13     centers = make_centers(kwargs)
#      14     radius = (centers[0][1] - centers[0][0]) / math.sqrt(3)
#      15     hexes = []
#
# <ipython-input-134-cc9e1ad84fbb> in make_centers(xmin, xmax, ymin, ymax, nrows)
#       2     row_spacing = (ymax - ymin) / nrows
#       3     col_spacing = 2 / math.sqrt(3) * row_spacing
# ----> 4     ncols = (xmax - xmin) / col_spacing
#       5     x = ([(c + 0.25) * col_spacing + xmin for c in range(int(ncols))]
#       6      + [(c + 0.75) * col_spacing + xmin for c in range(int(ncols))]) * int(nrows / 2)
#
# TypeError: unsupported operand type(s) for -: 'int' and 'dict'

# %%
import geopandas as gp

hexbins = gp.GeoDataFrame(geometry=hexes)
hexbins.crs = {'init': 'epsg:5070', 'no_defs': True}

# %%
hexbins.plot()

# %%
type(hexbins)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
hexbins['geometry'].to_crs(epsg=5070)
hexbins.plot()
